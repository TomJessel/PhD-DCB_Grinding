# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf
from autoencoder import AutoEncoder, VariationalAutoEncoder, LSTMAutoEncoder

import src
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import PurePosixPath as Path

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tf.config.set_visible_devices([], 'GPU')

# %%
HOME_DIR, BASE_DIR, CODE_DIR, TB_DIR, RMS_DATA_DIR = src.config_paths()
print(TB_DIR)
# Out:
# /mnt/c/Users/tomje/OneDrive - Cardiff University/Documents/PHD/AE/TensorBoard

# %% [markdown]
# # Load in RMS data for tests

# %%
# exps = ['Test 5', 'Test 7', 'Test 8', 'Test 9']
exps = ['Test 9']
rms = {}

for test in exps:
    rms[test] = src.ae.ae.RMS(test)
    rms[test].data.drop(['0', '1', '2',], axis=1, inplace=True)
    
try:
    rms['Test 5'].data.drop(['23', '24'], axis=1, inplace=True)
except KeyError:
    pass
# Out:
# --------------------------------------------------
# Loaded RMS data for "22_11_30_weartest_1000"
# Experiemnt No: Test 9
# Number of files: 158
# --------------------------------------------------

# %%
def remove_dc(sig):
    return sig - np.nanmean(sig)

for test in exps:
    rms[test]._data = rms[test].data.iloc[50:350, :].reset_index(drop=True)
    rms[test]._data = rms[test].data.apply(remove_dc, axis=0)

# %%
# Join 3 datasets for transfer learning
# training section is going to be first 70 cuts of each test

# dfs = [rms[test].data.iloc[:, :70].values for test in exps[:-1]]
# join_df = np.concatenate(dfs, axis=1)
# join_df = pd.DataFrame(join_df)
# print(np.shape(join_df))

# # Create RMS obj for the join_df data
# class join_rms_obj:
#     def __init__(self, data, exp_name):
#         self.data = data
#         self.exp_name = exp_name

# join_rms = join_rms_obj(join_df, 'join_df')
# exps = ['join_rms'] # FOR LSTMAE

# %%
r = rms[test].data.values
r.shape
plt.plot(r[:, 43])
plt.xlabel('Samples')
plt.ylabel('Rolling RMS (V)')
plt.autoscale(enable=True, axis='x', tight=True)
# plt.plot(r[:, 120])
# plt.plot(r[:, 145])

# %% [markdown]
# # Setup Autoencoder for each Test
# - The model is trained over a small section of the test depending on `train_slice`.
# - The model parameters are specified within the `params` dict.

# %%
autoe = {}
for test in exps:
        """
        autoe[test] = VariationalAutoEncoder(rms[test],
                                             rms[test].data,
                                             tb=False,
                                             tb_logdir=rms[test].exp_name,
                                             train_slice=(0, 75),
                                             val_frac=0.33,
                                             params={'latent_dim': 4,
                                                   'n_size': [64, 32],
                                                   'epochs': 1000,
                                                   'batch_size': 15,
                                                   'callbacks': [
                                                           tf.keras.callbacks.EarlyStopping(
                                                                monitor='val_loss',
                                                                patience=60,
                                                                mode='min',
                                                                start_from_epoch=100,
                                                           ),
                                                        ]
                                                   }
                                           )
        """
        # '''
        autoe[test] = AutoEncoder(rms[test],
                                  rms[test].data,
                                  tb=False,
                                  tb_logdir=rms[test].exp_name.upper().replace(' ', '_'),
                                  train_slice=(0, 50),
                                  val_frac=0.2,
                                  random_state=1,
                                  params={'n_bottleneck': 16,
                                          'n_size': [64, 32],
                                          'epochs': 1000,
                                          'batch_size': 10,
                                          'loss': 'mse',
                                          'dropout': 0.,
                                          'callbacks': [
                                                  tf.keras.callbacks.EarlyStopping(
                                                              monitor='val_loss',
                                                              patience=80,
                                                              mode='min',
                                                              start_from_epoch= 100,
                                                  ),
                                                #   tf.keras.callbacks.ReduceLROnPlateau(
                                                #                 monitor='val_loss',
                                                #                 mode='min',
                                                #                 patience=25,
                                                #                 factor=0.01,
                                                #   ),
                                                ]

                                          }
                                  )                                
        # '''
        '''
        autoe[test] = LSTMAutoEncoder(join_rms,
                                      join_rms.data,
                                      tb=True,
                                      tb_logdir='LSTMAE_test',
                                      train_slice=(0, 209),
                                      val_frac=0.33,
                                      params={'epochs': 300,
                                              'batch_size': 64,
                                              'n_size': [256, 128, 64],
                                              'seq_len': 100,
                                              'n_bottleneck': 32,
                                              'loss': 'mean_squared_error',
                                              'callbacks': [
                                                      tf.keras.callbacks.EarlyStopping(
                                                        monitor='val_loss',
                                                        patience=10,
                                                        mode='min',
                                                        start_from_epoch= 150,
                                                        ),
                                                 ]
                                      }
                                )
        '''
# Out:
# Pre-Processing Data:
# 	Training Data: slice(0, 50, None)
# 	Input train shape: (40, 300)
# 	Input val shape: (10, 300)
#
# AUTOE-Test_9-E-1000-L-[64, 32, 16, 32, 64]-20240129-155605

# %%
# add model checkpoint callback after creating model
for test in exps:
    name = autoe[test].run_name
    model_folder = TB_DIR.joinpath(autoe[test]._tb_logdir.joinpath(name))
    if not os.path.exists(model_folder):
       os.makedirs(model_folder)
    assert os.path.exists(model_folder)

    autoe[test].model.callbacks.append(
        tf.keras.callbacks.ModelCheckpoint(
        filepath=model_folder.joinpath(f'{name}.h5'),
        monitor='val_loss',
        mode='min',
        save_best_only=True,
        save_weights_only=True,
        )
    )

# %% [markdown]
# # Train each autoe on the training data
# - `x` is the inputted data for training, which is `autoe.train_data`
# - `val_data` is the validation data from `autoe.val_data`

# %%
for test in exps:
        autoe[test].fit(x=autoe[test].train_data,
                        val_data=autoe[test].val_data,
                        verbose=1,
                        use_multiprocessing=True,
                        )
# Out:
# Training model: AUTOE-Test_9-E-1000-L-[64, 32, 16, 32, 64]-20240129-155605:
# Epoch 1/1000
# 4/4 [==============================] - 2s 75ms/step - loss: 0.1628 - mean_squared_error: 0.1628 - mean_absolute_error: 0.3460 - r_squared: -18.5167 - val_loss: 0.1500 - val_mean_squared_error: 0.1500 - val_mean_absolute_error: 0.3581 - val_r_squared: -14.2366
# Epoch 2/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1559 - mean_squared_error: 0.1559 - mean_absolute_error: 0.3418 - r_squared: -16.8959 - val_loss: 0.1556 - val_mean_squared_error: 0.1556 - val_mean_absolute_error: 0.3673 - val_r_squared: -14.8719
# Epoch 3/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1463 - mean_squared_error: 0.1463 - mean_absolute_error: 0.3320 - r_squared: -16.0878 - val_loss: 0.1599 - val_mean_squared_error: 0.1599 - val_mean_absolute_error: 0.3741 - val_r_squared: -15.3474
# Epoch 4/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1354 - mean_squared_error: 0.1354 - mean_absolute_error: 0.3207 - r_squared: -14.2954 - val_loss: 0.1623 - val_mean_squared_error: 0.1623 - val_mean_absolute_error: 0.3778 - val_r_squared: -15.6199
# Epoch 5/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1272 - mean_squared_error: 0.1272 - mean_absolute_error: 0.3113 - r_squared: -13.2766 - val_loss: 0.1634 - val_mean_squared_error: 0.1634 - val_mean_absolute_error: 0.3796 - val_r_squared: -15.7540
# Epoch 6/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1265 - mean_squared_error: 0.1265 - mean_absolute_error: 0.3106 - r_squared: -13.6935 - val_loss: 0.1632 - val_mean_squared_error: 0.1632 - val_mean_absolute_error: 0.3796 - val_r_squared: -15.7404
# Epoch 7/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1228 - mean_squared_error: 0.1228 - mean_absolute_error: 0.3075 - r_squared: -13.4537 - val_loss: 0.1621 - val_mean_squared_error: 0.1621 - val_mean_absolute_error: 0.3783 - val_r_squared: -15.6347
# Epoch 8/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1173 - mean_squared_error: 0.1173 - mean_absolute_error: 0.2991 - r_squared: -12.2072 - val_loss: 0.1603 - val_mean_squared_error: 0.1603 - val_mean_absolute_error: 0.3760 - val_r_squared: -15.4510
# Epoch 9/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1144 - mean_squared_error: 0.1144 - mean_absolute_error: 0.2963 - r_squared: -12.0731 - val_loss: 0.1579 - val_mean_squared_error: 0.1579 - val_mean_absolute_error: 0.3729 - val_r_squared: -15.1942
# Epoch 10/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1125 - mean_squared_error: 0.1125 - mean_absolute_error: 0.2930 - r_squared: -11.7278 - val_loss: 0.1551 - val_mean_squared_error: 0.1551 - val_mean_absolute_error: 0.3692 - val_r_squared: -14.8972
# Epoch 11/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1100 - mean_squared_error: 0.1100 - mean_absolute_error: 0.2892 - r_squared: -11.7403 - val_loss: 0.1523 - val_mean_squared_error: 0.1523 - val_mean_absolute_error: 0.3654 - val_r_squared: -14.6139
# Epoch 12/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.1100 - mean_squared_error: 0.1100 - mean_absolute_error: 0.2896 - r_squared: -11.6833 - val_loss: 0.1493 - val_mean_squared_error: 0.1493 - val_mean_absolute_error: 0.3612 - val_r_squared: -14.2975
# Epoch 13/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.1046 - mean_squared_error: 0.1046 - mean_absolute_error: 0.2805 - r_squared: -11.9276 - val_loss: 0.1457 - val_mean_squared_error: 0.1457 - val_mean_absolute_error: 0.3561 - val_r_squared: -13.9290
# Epoch 14/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.1034 - mean_squared_error: 0.1034 - mean_absolute_error: 0.2783 - r_squared: -10.6857 - val_loss: 0.1417 - val_mean_squared_error: 0.1417 - val_mean_absolute_error: 0.3503 - val_r_squared: -13.5279
# Epoch 15/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0993 - mean_squared_error: 0.0993 - mean_absolute_error: 0.2721 - r_squared: -10.1977 - val_loss: 0.1376 - val_mean_squared_error: 0.1376 - val_mean_absolute_error: 0.3441 - val_r_squared: -13.1013
# Epoch 16/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0979 - mean_squared_error: 0.0979 - mean_absolute_error: 0.2695 - r_squared: -10.1529 - val_loss: 0.1333 - val_mean_squared_error: 0.1333 - val_mean_absolute_error: 0.3375 - val_r_squared: -12.6545
# Epoch 17/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0963 - mean_squared_error: 0.0963 - mean_absolute_error: 0.2670 - r_squared: -9.7996 - val_loss: 0.1290 - val_mean_squared_error: 0.1290 - val_mean_absolute_error: 0.3307 - val_r_squared: -12.2025
# Epoch 18/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0950 - mean_squared_error: 0.0950 - mean_absolute_error: 0.2646 - r_squared: -10.1000 - val_loss: 0.1246 - val_mean_squared_error: 0.1246 - val_mean_absolute_error: 0.3234 - val_r_squared: -11.7211
# Epoch 19/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0946 - mean_squared_error: 0.0946 - mean_absolute_error: 0.2635 - r_squared: -9.8429 - val_loss: 0.1200 - val_mean_squared_error: 0.1200 - val_mean_absolute_error: 0.3159 - val_r_squared: -11.2367
# Epoch 20/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0902 - mean_squared_error: 0.0902 - mean_absolute_error: 0.2550 - r_squared: -9.6199 - val_loss: 0.1157 - val_mean_squared_error: 0.1157 - val_mean_absolute_error: 0.3084 - val_r_squared: -10.7738
# Epoch 21/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0881 - mean_squared_error: 0.0881 - mean_absolute_error: 0.2517 - r_squared: -9.0872 - val_loss: 0.1111 - val_mean_squared_error: 0.1111 - val_mean_absolute_error: 0.3005 - val_r_squared: -10.2994
# Epoch 22/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0866 - mean_squared_error: 0.0866 - mean_absolute_error: 0.2488 - r_squared: -8.8958 - val_loss: 0.1062 - val_mean_squared_error: 0.1062 - val_mean_absolute_error: 0.2919 - val_r_squared: -9.7888
# Epoch 23/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0843 - mean_squared_error: 0.0843 - mean_absolute_error: 0.2438 - r_squared: -8.6737 - val_loss: 0.1012 - val_mean_squared_error: 0.1012 - val_mean_absolute_error: 0.2828 - val_r_squared: -9.2723
# Epoch 24/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0823 - mean_squared_error: 0.0823 - mean_absolute_error: 0.2401 - r_squared: -8.1941 - val_loss: 0.0964 - val_mean_squared_error: 0.0964 - val_mean_absolute_error: 0.2740 - val_r_squared: -8.7753
# Epoch 25/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0818 - mean_squared_error: 0.0818 - mean_absolute_error: 0.2386 - r_squared: -8.5608 - val_loss: 0.0920 - val_mean_squared_error: 0.0920 - val_mean_absolute_error: 0.2658 - val_r_squared: -8.3242
# Epoch 26/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0793 - mean_squared_error: 0.0793 - mean_absolute_error: 0.2343 - r_squared: -7.8372 - val_loss: 0.0879 - val_mean_squared_error: 0.0879 - val_mean_absolute_error: 0.2577 - val_r_squared: -7.8817
# Epoch 27/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0777 - mean_squared_error: 0.0777 - mean_absolute_error: 0.2306 - r_squared: -7.9713 - val_loss: 0.0836 - val_mean_squared_error: 0.0836 - val_mean_absolute_error: 0.2494 - val_r_squared: -7.4241
# Epoch 28/1000
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0758 - mean_squared_error: 0.0758 - mean_absolute_error: 0.2256 - r_squared: -7.8744 - val_loss: 0.0793 - val_mean_squared_error: 0.0793 - val_mean_absolute_error: 0.2409 - val_r_squared: -6.9639
# Epoch 29/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0729 - mean_squared_error: 0.0729 - mean_absolute_error: 0.2204 - r_squared: -7.9056 - val_loss: 0.0755 - val_mean_squared_error: 0.0755 - val_mean_absolute_error: 0.2330 - val_r_squared: -6.5563
# Epoch 30/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0751 - mean_squared_error: 0.0751 - mean_absolute_error: 0.2242 - r_squared: -7.8895 - val_loss: 0.0719 - val_mean_squared_error: 0.0719 - val_mean_absolute_error: 0.2255 - val_r_squared: -6.1842
# Epoch 31/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0735 - mean_squared_error: 0.0735 - mean_absolute_error: 0.2214 - r_squared: -7.6283 - val_loss: 0.0689 - val_mean_squared_error: 0.0689 - val_mean_absolute_error: 0.2190 - val_r_squared: -5.8829
# Epoch 32/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0683 - mean_squared_error: 0.0683 - mean_absolute_error: 0.2114 - r_squared: -7.2371 - val_loss: 0.0659 - val_mean_squared_error: 0.0659 - val_mean_absolute_error: 0.2124 - val_r_squared: -5.5892
# Epoch 33/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0662 - mean_squared_error: 0.0662 - mean_absolute_error: 0.2067 - r_squared: -6.6434 - val_loss: 0.0631 - val_mean_squared_error: 0.0631 - val_mean_absolute_error: 0.2062 - val_r_squared: -5.3278
# Epoch 34/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0635 - mean_squared_error: 0.0635 - mean_absolute_error: 0.1998 - r_squared: -6.4104 - val_loss: 0.0602 - val_mean_squared_error: 0.0602 - val_mean_absolute_error: 0.1999 - val_r_squared: -5.0306
# Epoch 35/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0647 - mean_squared_error: 0.0647 - mean_absolute_error: 0.2038 - r_squared: -6.4255 - val_loss: 0.0572 - val_mean_squared_error: 0.0572 - val_mean_absolute_error: 0.1933 - val_r_squared: -4.7140
# Epoch 36/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0633 - mean_squared_error: 0.0633 - mean_absolute_error: 0.2004 - r_squared: -6.3966 - val_loss: 0.0543 - val_mean_squared_error: 0.0543 - val_mean_absolute_error: 0.1868 - val_r_squared: -4.4135
# Epoch 37/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0645 - mean_squared_error: 0.0645 - mean_absolute_error: 0.2024 - r_squared: -6.3705 - val_loss: 0.0521 - val_mean_squared_error: 0.0521 - val_mean_absolute_error: 0.1816 - val_r_squared: -4.1833
# Epoch 38/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0635 - mean_squared_error: 0.0635 - mean_absolute_error: 0.2013 - r_squared: -6.4110 - val_loss: 0.0502 - val_mean_squared_error: 0.0502 - val_mean_absolute_error: 0.1772 - val_r_squared: -3.9699
# Epoch 39/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0631 - mean_squared_error: 0.0631 - mean_absolute_error: 0.1990 - r_squared: -6.3003 - val_loss: 0.0481 - val_mean_squared_error: 0.0481 - val_mean_absolute_error: 0.1722 - val_r_squared: -3.7398
# Epoch 40/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0608 - mean_squared_error: 0.0608 - mean_absolute_error: 0.1949 - r_squared: -5.8831 - val_loss: 0.0460 - val_mean_squared_error: 0.0460 - val_mean_absolute_error: 0.1671 - val_r_squared: -3.5127
# Epoch 41/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0572 - mean_squared_error: 0.0572 - mean_absolute_error: 0.1865 - r_squared: -5.8044 - val_loss: 0.0439 - val_mean_squared_error: 0.0439 - val_mean_absolute_error: 0.1624 - val_r_squared: -3.3061
# Epoch 42/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0586 - mean_squared_error: 0.0586 - mean_absolute_error: 0.1903 - r_squared: -5.8247 - val_loss: 0.0424 - val_mean_squared_error: 0.0424 - val_mean_absolute_error: 0.1591 - val_r_squared: -3.1771
# Epoch 43/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0564 - mean_squared_error: 0.0564 - mean_absolute_error: 0.1854 - r_squared: -5.8276 - val_loss: 0.0407 - val_mean_squared_error: 0.0407 - val_mean_absolute_error: 0.1553 - val_r_squared: -3.0274
# Epoch 44/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0495 - mean_squared_error: 0.0495 - mean_absolute_error: 0.1687 - r_squared: -4.5651 - val_loss: 0.0391 - val_mean_squared_error: 0.0391 - val_mean_absolute_error: 0.1517 - val_r_squared: -2.8844
# Epoch 45/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0529 - mean_squared_error: 0.0529 - mean_absolute_error: 0.1762 - r_squared: -5.1296 - val_loss: 0.0379 - val_mean_squared_error: 0.0379 - val_mean_absolute_error: 0.1488 - val_r_squared: -2.7702
# Epoch 46/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0551 - mean_squared_error: 0.0551 - mean_absolute_error: 0.1827 - r_squared: -6.1668 - val_loss: 0.0369 - val_mean_squared_error: 0.0369 - val_mean_absolute_error: 0.1464 - val_r_squared: -2.6690
# Epoch 47/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0499 - mean_squared_error: 0.0499 - mean_absolute_error: 0.1713 - r_squared: -4.6356 - val_loss: 0.0358 - val_mean_squared_error: 0.0358 - val_mean_absolute_error: 0.1441 - val_r_squared: -2.5884
# Epoch 48/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0523 - mean_squared_error: 0.0523 - mean_absolute_error: 0.1761 - r_squared: -5.4749 - val_loss: 0.0344 - val_mean_squared_error: 0.0344 - val_mean_absolute_error: 0.1412 - val_r_squared: -2.4715
# Epoch 49/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0497 - mean_squared_error: 0.0497 - mean_absolute_error: 0.1695 - r_squared: -5.0365 - val_loss: 0.0334 - val_mean_squared_error: 0.0334 - val_mean_absolute_error: 0.1391 - val_r_squared: -2.3759
# Epoch 50/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0471 - mean_squared_error: 0.0471 - mean_absolute_error: 0.1630 - r_squared: -4.2151 - val_loss: 0.0325 - val_mean_squared_error: 0.0325 - val_mean_absolute_error: 0.1372 - val_r_squared: -2.2847
# Epoch 51/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0506 - mean_squared_error: 0.0506 - mean_absolute_error: 0.1715 - r_squared: -4.9547 - val_loss: 0.0319 - val_mean_squared_error: 0.0319 - val_mean_absolute_error: 0.1357 - val_r_squared: -2.2263
# Epoch 52/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0508 - mean_squared_error: 0.0508 - mean_absolute_error: 0.1726 - r_squared: -5.1103 - val_loss: 0.0317 - val_mean_squared_error: 0.0317 - val_mean_absolute_error: 0.1351 - val_r_squared: -2.2035
# Epoch 53/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0488 - mean_squared_error: 0.0488 - mean_absolute_error: 0.1681 - r_squared: -4.5361 - val_loss: 0.0316 - val_mean_squared_error: 0.0316 - val_mean_absolute_error: 0.1344 - val_r_squared: -2.1868
# Epoch 54/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0473 - mean_squared_error: 0.0473 - mean_absolute_error: 0.1643 - r_squared: -4.4067 - val_loss: 0.0311 - val_mean_squared_error: 0.0311 - val_mean_absolute_error: 0.1331 - val_r_squared: -2.1346
# Epoch 55/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0446 - mean_squared_error: 0.0446 - mean_absolute_error: 0.1586 - r_squared: -4.1067 - val_loss: 0.0305 - val_mean_squared_error: 0.0305 - val_mean_absolute_error: 0.1318 - val_r_squared: -2.0640
# Epoch 56/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0426 - mean_squared_error: 0.0426 - mean_absolute_error: 0.1529 - r_squared: -3.9621 - val_loss: 0.0298 - val_mean_squared_error: 0.0298 - val_mean_absolute_error: 0.1303 - val_r_squared: -2.0007
# Epoch 57/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0464 - mean_squared_error: 0.0464 - mean_absolute_error: 0.1631 - r_squared: -4.2283 - val_loss: 0.0291 - val_mean_squared_error: 0.0291 - val_mean_absolute_error: 0.1285 - val_r_squared: -1.9405
# Epoch 58/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0466 - mean_squared_error: 0.0466 - mean_absolute_error: 0.1632 - r_squared: -4.2898 - val_loss: 0.0285 - val_mean_squared_error: 0.0285 - val_mean_absolute_error: 0.1272 - val_r_squared: -1.8913
# Epoch 59/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0405 - mean_squared_error: 0.0405 - mean_absolute_error: 0.1501 - r_squared: -3.4149 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1268 - val_r_squared: -1.8810
# Epoch 60/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0437 - mean_squared_error: 0.0437 - mean_absolute_error: 0.1560 - r_squared: -4.2048 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1271 - val_r_squared: -1.9048
# Epoch 61/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0441 - mean_squared_error: 0.0441 - mean_absolute_error: 0.1574 - r_squared: -3.9863 - val_loss: 0.0281 - val_mean_squared_error: 0.0281 - val_mean_absolute_error: 0.1266 - val_r_squared: -1.8980
# Epoch 62/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0455 - mean_squared_error: 0.0455 - mean_absolute_error: 0.1612 - r_squared: -4.0410 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1267 - val_r_squared: -1.9320
# Epoch 63/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0396 - mean_squared_error: 0.0396 - mean_absolute_error: 0.1474 - r_squared: -3.4897 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1266 - val_r_squared: -1.9294
# Epoch 64/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0380 - mean_squared_error: 0.0380 - mean_absolute_error: 0.1439 - r_squared: -3.4769 - val_loss: 0.0281 - val_mean_squared_error: 0.0281 - val_mean_absolute_error: 0.1260 - val_r_squared: -1.9026
# Epoch 65/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0403 - mean_squared_error: 0.0403 - mean_absolute_error: 0.1496 - r_squared: -3.6422 - val_loss: 0.0270 - val_mean_squared_error: 0.0270 - val_mean_absolute_error: 0.1234 - val_r_squared: -1.8105
# Epoch 66/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0405 - mean_squared_error: 0.0405 - mean_absolute_error: 0.1517 - r_squared: -4.0780 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.1223 - val_r_squared: -1.7616
# Epoch 67/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0354 - mean_squared_error: 0.0354 - mean_absolute_error: 0.1384 - r_squared: -3.0777 - val_loss: 0.0260 - val_mean_squared_error: 0.0260 - val_mean_absolute_error: 0.1219 - val_r_squared: -1.7528
# Epoch 68/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0381 - mean_squared_error: 0.0381 - mean_absolute_error: 0.1450 - r_squared: -3.2774 - val_loss: 0.0259 - val_mean_squared_error: 0.0259 - val_mean_absolute_error: 0.1222 - val_r_squared: -1.7572
# Epoch 69/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0385 - mean_squared_error: 0.0385 - mean_absolute_error: 0.1457 - r_squared: -3.2442 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - val_mean_absolute_error: 0.1222 - val_r_squared: -1.7274
# Epoch 70/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0362 - mean_squared_error: 0.0362 - mean_absolute_error: 0.1410 - r_squared: -3.1141 - val_loss: 0.0254 - val_mean_squared_error: 0.0254 - val_mean_absolute_error: 0.1220 - val_r_squared: -1.6995
# Epoch 71/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0341 - mean_squared_error: 0.0341 - mean_absolute_error: 0.1354 - r_squared: -2.8241 - val_loss: 0.0251 - val_mean_squared_error: 0.0251 - val_mean_absolute_error: 0.1216 - val_r_squared: -1.6846
# Epoch 72/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0372 - mean_squared_error: 0.0372 - mean_absolute_error: 0.1429 - r_squared: -3.3431 - val_loss: 0.0244 - val_mean_squared_error: 0.0244 - val_mean_absolute_error: 0.1200 - val_r_squared: -1.6131
# Epoch 73/1000
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0329 - mean_squared_error: 0.0329 - mean_absolute_error: 0.1332 - r_squared: -2.6915 - val_loss: 0.0242 - val_mean_squared_error: 0.0242 - val_mean_absolute_error: 0.1193 - val_r_squared: -1.5716
# Epoch 74/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0313 - mean_squared_error: 0.0313 - mean_absolute_error: 0.1287 - r_squared: -2.5657 - val_loss: 0.0239 - val_mean_squared_error: 0.0239 - val_mean_absolute_error: 0.1183 - val_r_squared: -1.5322
# Epoch 75/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0300 - mean_squared_error: 0.0300 - mean_absolute_error: 0.1275 - r_squared: -2.3002 - val_loss: 0.0237 - val_mean_squared_error: 0.0237 - val_mean_absolute_error: 0.1176 - val_r_squared: -1.5059
# Epoch 76/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0301 - mean_squared_error: 0.0301 - mean_absolute_error: 0.1266 - r_squared: -2.2352 - val_loss: 0.0238 - val_mean_squared_error: 0.0238 - val_mean_absolute_error: 0.1178 - val_r_squared: -1.5296
# Epoch 77/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0303 - mean_squared_error: 0.0303 - mean_absolute_error: 0.1276 - r_squared: -2.4182 - val_loss: 0.0235 - val_mean_squared_error: 0.0235 - val_mean_absolute_error: 0.1169 - val_r_squared: -1.5037
# Epoch 78/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0354 - mean_squared_error: 0.0354 - mean_absolute_error: 0.1401 - r_squared: -3.1517 - val_loss: 0.0232 - val_mean_squared_error: 0.0232 - val_mean_absolute_error: 0.1159 - val_r_squared: -1.4661
# Epoch 79/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0301 - mean_squared_error: 0.0301 - mean_absolute_error: 0.1263 - r_squared: -2.3903 - val_loss: 0.0229 - val_mean_squared_error: 0.0229 - val_mean_absolute_error: 0.1152 - val_r_squared: -1.4196
# Epoch 80/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0332 - mean_squared_error: 0.0332 - mean_absolute_error: 0.1334 - r_squared: -2.6423 - val_loss: 0.0221 - val_mean_squared_error: 0.0221 - val_mean_absolute_error: 0.1134 - val_r_squared: -1.3126
# Epoch 81/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0320 - mean_squared_error: 0.0320 - mean_absolute_error: 0.1317 - r_squared: -2.7751 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.1120 - val_r_squared: -1.2228
# Epoch 82/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0324 - mean_squared_error: 0.0324 - mean_absolute_error: 0.1338 - r_squared: -2.7896 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - val_mean_absolute_error: 0.1108 - val_r_squared: -1.1457
# Epoch 83/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0303 - mean_squared_error: 0.0303 - mean_absolute_error: 0.1275 - r_squared: -2.4385 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - val_mean_absolute_error: 0.1113 - val_r_squared: -1.1533
# Epoch 84/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0278 - mean_squared_error: 0.0278 - mean_absolute_error: 0.1220 - r_squared: -1.9336 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.1120 - val_r_squared: -1.1737
# Epoch 85/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0277 - mean_squared_error: 0.0277 - mean_absolute_error: 0.1205 - r_squared: -2.1058 - val_loss: 0.0216 - val_mean_squared_error: 0.0216 - val_mean_absolute_error: 0.1123 - val_r_squared: -1.1891
# Epoch 86/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0300 - mean_squared_error: 0.0300 - mean_absolute_error: 0.1276 - r_squared: -2.3055 - val_loss: 0.0220 - val_mean_squared_error: 0.0220 - val_mean_absolute_error: 0.1133 - val_r_squared: -1.2393
# Epoch 87/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0324 - mean_squared_error: 0.0324 - mean_absolute_error: 0.1321 - r_squared: -2.6809 - val_loss: 0.0233 - val_mean_squared_error: 0.0233 - val_mean_absolute_error: 0.1159 - val_r_squared: -1.4035
# Epoch 88/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0250 - mean_squared_error: 0.0250 - mean_absolute_error: 0.1145 - r_squared: -1.6380 - val_loss: 0.0236 - val_mean_squared_error: 0.0236 - val_mean_absolute_error: 0.1162 - val_r_squared: -1.4324
# Epoch 89/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0254 - mean_squared_error: 0.0254 - mean_absolute_error: 0.1157 - r_squared: -1.7541 - val_loss: 0.0235 - val_mean_squared_error: 0.0235 - val_mean_absolute_error: 0.1159 - val_r_squared: -1.4268
# Epoch 90/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0252 - mean_squared_error: 0.0252 - mean_absolute_error: 0.1147 - r_squared: -1.8456 - val_loss: 0.0231 - val_mean_squared_error: 0.0231 - val_mean_absolute_error: 0.1149 - val_r_squared: -1.3747
# Epoch 91/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0279 - mean_squared_error: 0.0279 - mean_absolute_error: 0.1213 - r_squared: -2.0730 - val_loss: 0.0231 - val_mean_squared_error: 0.0231 - val_mean_absolute_error: 0.1150 - val_r_squared: -1.3816
# Epoch 92/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0235 - mean_squared_error: 0.0235 - mean_absolute_error: 0.1105 - r_squared: -1.5854 - val_loss: 0.0232 - val_mean_squared_error: 0.0232 - val_mean_absolute_error: 0.1152 - val_r_squared: -1.3945
# Epoch 93/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0235 - mean_squared_error: 0.0235 - mean_absolute_error: 0.1108 - r_squared: -1.6423 - val_loss: 0.0233 - val_mean_squared_error: 0.0233 - val_mean_absolute_error: 0.1152 - val_r_squared: -1.3896
# Epoch 94/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0270 - mean_squared_error: 0.0270 - mean_absolute_error: 0.1190 - r_squared: -2.0181 - val_loss: 0.0231 - val_mean_squared_error: 0.0231 - val_mean_absolute_error: 0.1146 - val_r_squared: -1.3714
# Epoch 95/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0260 - mean_squared_error: 0.0260 - mean_absolute_error: 0.1162 - r_squared: -2.0258 - val_loss: 0.0229 - val_mean_squared_error: 0.0229 - val_mean_absolute_error: 0.1144 - val_r_squared: -1.3736
# Epoch 96/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0251 - mean_squared_error: 0.0251 - mean_absolute_error: 0.1151 - r_squared: -1.8869 - val_loss: 0.0230 - val_mean_squared_error: 0.0230 - val_mean_absolute_error: 0.1148 - val_r_squared: -1.3879
# Epoch 97/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - mean_absolute_error: 0.1089 - r_squared: -1.5096 - val_loss: 0.0230 - val_mean_squared_error: 0.0230 - val_mean_absolute_error: 0.1153 - val_r_squared: -1.3971
# Epoch 98/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - mean_absolute_error: 0.1096 - r_squared: -1.7077 - val_loss: 0.0226 - val_mean_squared_error: 0.0226 - val_mean_absolute_error: 0.1139 - val_r_squared: -1.3271
# Epoch 99/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0241 - mean_squared_error: 0.0241 - mean_absolute_error: 0.1124 - r_squared: -1.6508 - val_loss: 0.0220 - val_mean_squared_error: 0.0220 - val_mean_absolute_error: 0.1124 - val_r_squared: -1.2616
# Epoch 100/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - mean_absolute_error: 0.1094 - r_squared: -1.6074 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - val_mean_absolute_error: 0.1115 - val_r_squared: -1.2177
# Epoch 101/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0201 - mean_squared_error: 0.0201 - mean_absolute_error: 0.1022 - r_squared: -1.2677 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - val_mean_absolute_error: 0.1103 - val_r_squared: -1.1703
# Epoch 102/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0223 - mean_squared_error: 0.0223 - mean_absolute_error: 0.1090 - r_squared: -1.6142 - val_loss: 0.0209 - val_mean_squared_error: 0.0209 - val_mean_absolute_error: 0.1096 - val_r_squared: -1.1459
# Epoch 103/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0198 - mean_squared_error: 0.0198 - mean_absolute_error: 0.1012 - r_squared: -1.1431 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - val_mean_absolute_error: 0.1102 - val_r_squared: -1.1745
# Epoch 104/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0217 - mean_squared_error: 0.0217 - mean_absolute_error: 0.1064 - r_squared: -1.5016 - val_loss: 0.0209 - val_mean_squared_error: 0.0209 - val_mean_absolute_error: 0.1100 - val_r_squared: -1.1638
# Epoch 105/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0221 - mean_squared_error: 0.0221 - mean_absolute_error: 0.1079 - r_squared: -1.5376 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.1095 - val_r_squared: -1.1305
# Epoch 106/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0212 - mean_squared_error: 0.0212 - mean_absolute_error: 0.1057 - r_squared: -1.2639 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.1097 - val_r_squared: -1.1268
# Epoch 107/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0193 - mean_squared_error: 0.0193 - mean_absolute_error: 0.0996 - r_squared: -1.0735 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.1099 - val_r_squared: -1.1292
# Epoch 108/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0195 - mean_squared_error: 0.0195 - mean_absolute_error: 0.0997 - r_squared: -1.0723 - val_loss: 0.0206 - val_mean_squared_error: 0.0206 - val_mean_absolute_error: 0.1096 - val_r_squared: -1.1192
# Epoch 109/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0191 - mean_squared_error: 0.0191 - mean_absolute_error: 0.0994 - r_squared: -1.1509 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.1087 - val_r_squared: -1.0725
# Epoch 110/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0197 - mean_squared_error: 0.0197 - mean_absolute_error: 0.1015 - r_squared: -1.1762 - val_loss: 0.0198 - val_mean_squared_error: 0.0198 - val_mean_absolute_error: 0.1079 - val_r_squared: -1.0331
# Epoch 111/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0191 - mean_squared_error: 0.0191 - mean_absolute_error: 0.1002 - r_squared: -1.1264 - val_loss: 0.0197 - val_mean_squared_error: 0.0197 - val_mean_absolute_error: 0.1076 - val_r_squared: -1.0215
# Epoch 112/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0187 - mean_squared_error: 0.0187 - mean_absolute_error: 0.0985 - r_squared: -1.0724 - val_loss: 0.0196 - val_mean_squared_error: 0.0196 - val_mean_absolute_error: 0.1073 - val_r_squared: -0.9975
# Epoch 113/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0188 - mean_squared_error: 0.0188 - mean_absolute_error: 0.0994 - r_squared: -1.0024 - val_loss: 0.0195 - val_mean_squared_error: 0.0195 - val_mean_absolute_error: 0.1069 - val_r_squared: -0.9768
# Epoch 114/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0191 - mean_squared_error: 0.0191 - mean_absolute_error: 0.0997 - r_squared: -1.0925 - val_loss: 0.0193 - val_mean_squared_error: 0.0193 - val_mean_absolute_error: 0.1066 - val_r_squared: -0.9617
# Epoch 115/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - mean_absolute_error: 0.0940 - r_squared: -0.8271 - val_loss: 0.0192 - val_mean_squared_error: 0.0192 - val_mean_absolute_error: 0.1061 - val_r_squared: -0.9521
# Epoch 116/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0178 - mean_squared_error: 0.0178 - mean_absolute_error: 0.0962 - r_squared: -0.9830 - val_loss: 0.0192 - val_mean_squared_error: 0.0192 - val_mean_absolute_error: 0.1057 - val_r_squared: -0.9524
# Epoch 117/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0200 - mean_squared_error: 0.0200 - mean_absolute_error: 0.1029 - r_squared: -1.2068 - val_loss: 0.0193 - val_mean_squared_error: 0.0193 - val_mean_absolute_error: 0.1059 - val_r_squared: -0.9552
# Epoch 118/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0178 - mean_squared_error: 0.0178 - mean_absolute_error: 0.0963 - r_squared: -0.9016 - val_loss: 0.0192 - val_mean_squared_error: 0.0192 - val_mean_absolute_error: 0.1059 - val_r_squared: -0.9449
# Epoch 119/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0187 - mean_squared_error: 0.0187 - mean_absolute_error: 0.0986 - r_squared: -1.1173 - val_loss: 0.0193 - val_mean_squared_error: 0.0193 - val_mean_absolute_error: 0.1061 - val_r_squared: -0.9491
# Epoch 120/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - mean_absolute_error: 0.0949 - r_squared: -0.9179 - val_loss: 0.0194 - val_mean_squared_error: 0.0194 - val_mean_absolute_error: 0.1062 - val_r_squared: -0.9552
# Epoch 121/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0245 - mean_squared_error: 0.0245 - mean_absolute_error: 0.1146 - r_squared: -1.8991 - val_loss: 0.0194 - val_mean_squared_error: 0.0194 - val_mean_absolute_error: 0.1063 - val_r_squared: -0.9570
# Epoch 122/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0167 - mean_squared_error: 0.0167 - mean_absolute_error: 0.0936 - r_squared: -0.7477 - val_loss: 0.0192 - val_mean_squared_error: 0.0192 - val_mean_absolute_error: 0.1059 - val_r_squared: -0.9407
# Epoch 123/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - mean_absolute_error: 0.0952 - r_squared: -0.9347 - val_loss: 0.0188 - val_mean_squared_error: 0.0188 - val_mean_absolute_error: 0.1049 - val_r_squared: -0.9050
# Epoch 124/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - mean_absolute_error: 0.0949 - r_squared: -0.9435 - val_loss: 0.0186 - val_mean_squared_error: 0.0186 - val_mean_absolute_error: 0.1048 - val_r_squared: -0.8826
# Epoch 125/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0168 - mean_squared_error: 0.0168 - mean_absolute_error: 0.0951 - r_squared: -0.8515 - val_loss: 0.0184 - val_mean_squared_error: 0.0184 - val_mean_absolute_error: 0.1045 - val_r_squared: -0.8564
# Epoch 126/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0153 - mean_squared_error: 0.0153 - mean_absolute_error: 0.0909 - r_squared: -0.6166 - val_loss: 0.0183 - val_mean_squared_error: 0.0183 - val_mean_absolute_error: 0.1045 - val_r_squared: -0.8456
# Epoch 127/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0181 - mean_squared_error: 0.0181 - mean_absolute_error: 0.0995 - r_squared: -0.9740 - val_loss: 0.0184 - val_mean_squared_error: 0.0184 - val_mean_absolute_error: 0.1047 - val_r_squared: -0.8543
# Epoch 128/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - mean_absolute_error: 0.0950 - r_squared: -0.7887 - val_loss: 0.0185 - val_mean_squared_error: 0.0185 - val_mean_absolute_error: 0.1041 - val_r_squared: -0.8498
# Epoch 129/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - mean_absolute_error: 0.0925 - r_squared: -0.6680 - val_loss: 0.0183 - val_mean_squared_error: 0.0183 - val_mean_absolute_error: 0.1032 - val_r_squared: -0.8272
# Epoch 130/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - mean_absolute_error: 0.0934 - r_squared: -0.7364 - val_loss: 0.0181 - val_mean_squared_error: 0.0181 - val_mean_absolute_error: 0.1026 - val_r_squared: -0.8090
# Epoch 131/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - mean_absolute_error: 0.0952 - r_squared: -0.8717 - val_loss: 0.0179 - val_mean_squared_error: 0.0179 - val_mean_absolute_error: 0.1022 - val_r_squared: -0.7966
# Epoch 132/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0152 - mean_squared_error: 0.0152 - mean_absolute_error: 0.0910 - r_squared: -0.6204 - val_loss: 0.0178 - val_mean_squared_error: 0.0178 - val_mean_absolute_error: 0.1018 - val_r_squared: -0.7762
# Epoch 133/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0139 - mean_squared_error: 0.0139 - mean_absolute_error: 0.0875 - r_squared: -0.4795 - val_loss: 0.0177 - val_mean_squared_error: 0.0177 - val_mean_absolute_error: 0.1015 - val_r_squared: -0.7636
# Epoch 134/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0154 - mean_squared_error: 0.0154 - mean_absolute_error: 0.0927 - r_squared: -0.6440 - val_loss: 0.0176 - val_mean_squared_error: 0.0176 - val_mean_absolute_error: 0.1012 - val_r_squared: -0.7481
# Epoch 135/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - mean_absolute_error: 0.0874 - r_squared: -0.4320 - val_loss: 0.0175 - val_mean_squared_error: 0.0175 - val_mean_absolute_error: 0.1008 - val_r_squared: -0.7426
# Epoch 136/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0169 - mean_squared_error: 0.0169 - mean_absolute_error: 0.0976 - r_squared: -0.9470 - val_loss: 0.0177 - val_mean_squared_error: 0.0177 - val_mean_absolute_error: 0.1015 - val_r_squared: -0.7689
# Epoch 137/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - mean_absolute_error: 0.0896 - r_squared: -0.5358 - val_loss: 0.0179 - val_mean_squared_error: 0.0179 - val_mean_absolute_error: 0.1023 - val_r_squared: -0.7879
# Epoch 138/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - mean_absolute_error: 0.0893 - r_squared: -0.5776 - val_loss: 0.0177 - val_mean_squared_error: 0.0177 - val_mean_absolute_error: 0.1023 - val_r_squared: -0.7675
# Epoch 139/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - mean_absolute_error: 0.0863 - r_squared: -0.4723 - val_loss: 0.0174 - val_mean_squared_error: 0.0174 - val_mean_absolute_error: 0.1019 - val_r_squared: -0.7351
# Epoch 140/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0153 - mean_squared_error: 0.0153 - mean_absolute_error: 0.0918 - r_squared: -0.6745 - val_loss: 0.0170 - val_mean_squared_error: 0.0170 - val_mean_absolute_error: 0.1009 - val_r_squared: -0.6852
# Epoch 141/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0153 - mean_squared_error: 0.0153 - mean_absolute_error: 0.0916 - r_squared: -0.6887 - val_loss: 0.0166 - val_mean_squared_error: 0.0166 - val_mean_absolute_error: 0.0998 - val_r_squared: -0.6409
# Epoch 142/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0152 - mean_squared_error: 0.0152 - mean_absolute_error: 0.0914 - r_squared: -0.7168 - val_loss: 0.0161 - val_mean_squared_error: 0.0161 - val_mean_absolute_error: 0.0988 - val_r_squared: -0.5920
# Epoch 143/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - mean_absolute_error: 0.0877 - r_squared: -0.5570 - val_loss: 0.0159 - val_mean_squared_error: 0.0159 - val_mean_absolute_error: 0.0981 - val_r_squared: -0.5674
# Epoch 144/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0133 - mean_squared_error: 0.0133 - mean_absolute_error: 0.0865 - r_squared: -0.4246 - val_loss: 0.0158 - val_mean_squared_error: 0.0158 - val_mean_absolute_error: 0.0980 - val_r_squared: -0.5427
# Epoch 145/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - mean_absolute_error: 0.0858 - r_squared: -0.3733 - val_loss: 0.0157 - val_mean_squared_error: 0.0157 - val_mean_absolute_error: 0.0981 - val_r_squared: -0.5171
# Epoch 146/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - mean_absolute_error: 0.0864 - r_squared: -0.4502 - val_loss: 0.0155 - val_mean_squared_error: 0.0155 - val_mean_absolute_error: 0.0976 - val_r_squared: -0.4787
# Epoch 147/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - mean_absolute_error: 0.0906 - r_squared: -0.6452 - val_loss: 0.0153 - val_mean_squared_error: 0.0153 - val_mean_absolute_error: 0.0968 - val_r_squared: -0.4426
# Epoch 148/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0133 - mean_squared_error: 0.0133 - mean_absolute_error: 0.0859 - r_squared: -0.3863 - val_loss: 0.0149 - val_mean_squared_error: 0.0149 - val_mean_absolute_error: 0.0957 - val_r_squared: -0.4152
# Epoch 149/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0139 - mean_squared_error: 0.0139 - mean_absolute_error: 0.0880 - r_squared: -0.4755 - val_loss: 0.0147 - val_mean_squared_error: 0.0147 - val_mean_absolute_error: 0.0950 - val_r_squared: -0.3928
# Epoch 150/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0137 - mean_squared_error: 0.0137 - mean_absolute_error: 0.0873 - r_squared: -0.4570 - val_loss: 0.0146 - val_mean_squared_error: 0.0146 - val_mean_absolute_error: 0.0949 - val_r_squared: -0.3862
# Epoch 151/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - mean_absolute_error: 0.0825 - r_squared: -0.2970 - val_loss: 0.0145 - val_mean_squared_error: 0.0145 - val_mean_absolute_error: 0.0948 - val_r_squared: -0.3650
# Epoch 152/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - mean_absolute_error: 0.0871 - r_squared: -0.4169 - val_loss: 0.0144 - val_mean_squared_error: 0.0144 - val_mean_absolute_error: 0.0945 - val_r_squared: -0.3523
# Epoch 153/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - mean_absolute_error: 0.0823 - r_squared: -0.2650 - val_loss: 0.0144 - val_mean_squared_error: 0.0144 - val_mean_absolute_error: 0.0944 - val_r_squared: -0.3536
# Epoch 154/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - mean_absolute_error: 0.0876 - r_squared: -0.5473 - val_loss: 0.0144 - val_mean_squared_error: 0.0144 - val_mean_absolute_error: 0.0945 - val_r_squared: -0.3541
# Epoch 155/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - mean_absolute_error: 0.0848 - r_squared: -0.3380 - val_loss: 0.0142 - val_mean_squared_error: 0.0142 - val_mean_absolute_error: 0.0938 - val_r_squared: -0.3246
# Epoch 156/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - mean_absolute_error: 0.0824 - r_squared: -0.2542 - val_loss: 0.0141 - val_mean_squared_error: 0.0141 - val_mean_absolute_error: 0.0936 - val_r_squared: -0.3174
# Epoch 157/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0134 - mean_squared_error: 0.0134 - mean_absolute_error: 0.0873 - r_squared: -0.5254 - val_loss: 0.0139 - val_mean_squared_error: 0.0139 - val_mean_absolute_error: 0.0931 - val_r_squared: -0.3071
# Epoch 158/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - mean_absolute_error: 0.0832 - r_squared: -0.2433 - val_loss: 0.0137 - val_mean_squared_error: 0.0137 - val_mean_absolute_error: 0.0926 - val_r_squared: -0.2947
# Epoch 159/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - mean_absolute_error: 0.0825 - r_squared: -0.2794 - val_loss: 0.0137 - val_mean_squared_error: 0.0137 - val_mean_absolute_error: 0.0925 - val_r_squared: -0.2891
# Epoch 160/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - mean_absolute_error: 0.0803 - r_squared: -0.1567 - val_loss: 0.0137 - val_mean_squared_error: 0.0137 - val_mean_absolute_error: 0.0924 - val_r_squared: -0.2796
# Epoch 161/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - mean_absolute_error: 0.0826 - r_squared: -0.2736 - val_loss: 0.0136 - val_mean_squared_error: 0.0136 - val_mean_absolute_error: 0.0919 - val_r_squared: -0.2616
# Epoch 162/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - mean_absolute_error: 0.0868 - r_squared: -0.4706 - val_loss: 0.0135 - val_mean_squared_error: 0.0135 - val_mean_absolute_error: 0.0917 - val_r_squared: -0.2535
# Epoch 163/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0819 - r_squared: -0.2561 - val_loss: 0.0135 - val_mean_squared_error: 0.0135 - val_mean_absolute_error: 0.0916 - val_r_squared: -0.2505
# Epoch 164/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - mean_absolute_error: 0.0846 - r_squared: -0.2980 - val_loss: 0.0133 - val_mean_squared_error: 0.0133 - val_mean_absolute_error: 0.0909 - val_r_squared: -0.2402
# Epoch 165/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - mean_absolute_error: 0.0815 - r_squared: -0.2110 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - val_mean_absolute_error: 0.0907 - val_r_squared: -0.2372
# Epoch 166/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - mean_absolute_error: 0.0831 - r_squared: -0.2495 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - val_mean_absolute_error: 0.0907 - val_r_squared: -0.2291
# Epoch 167/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - mean_absolute_error: 0.0821 - r_squared: -0.2481 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - val_mean_absolute_error: 0.0906 - val_r_squared: -0.2169
# Epoch 168/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - mean_absolute_error: 0.0795 - r_squared: -0.1661 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - val_mean_absolute_error: 0.0906 - val_r_squared: -0.2068
# Epoch 169/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - mean_absolute_error: 0.0830 - r_squared: -0.2975 - val_loss: 0.0129 - val_mean_squared_error: 0.0129 - val_mean_absolute_error: 0.0900 - val_r_squared: -0.1950
# Epoch 170/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - mean_absolute_error: 0.0807 - r_squared: -0.1605 - val_loss: 0.0128 - val_mean_squared_error: 0.0128 - val_mean_absolute_error: 0.0895 - val_r_squared: -0.1869
# Epoch 171/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - mean_absolute_error: 0.0816 - r_squared: -0.2147 - val_loss: 0.0127 - val_mean_squared_error: 0.0127 - val_mean_absolute_error: 0.0893 - val_r_squared: -0.1839
# Epoch 172/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - mean_absolute_error: 0.0811 - r_squared: -0.2018 - val_loss: 0.0126 - val_mean_squared_error: 0.0126 - val_mean_absolute_error: 0.0895 - val_r_squared: -0.1801
# Epoch 173/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0108 - mean_squared_error: 0.0108 - mean_absolute_error: 0.0796 - r_squared: -0.1560 - val_loss: 0.0127 - val_mean_squared_error: 0.0127 - val_mean_absolute_error: 0.0896 - val_r_squared: -0.1916
# Epoch 174/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - mean_absolute_error: 0.0798 - r_squared: -0.1773 - val_loss: 0.0127 - val_mean_squared_error: 0.0127 - val_mean_absolute_error: 0.0898 - val_r_squared: -0.1963
# Epoch 175/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - mean_absolute_error: 0.0831 - r_squared: -0.3155 - val_loss: 0.0127 - val_mean_squared_error: 0.0127 - val_mean_absolute_error: 0.0896 - val_r_squared: -0.1842
# Epoch 176/1000
# ...
# Epoch 358/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0666 - r_squared: 0.2698 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - val_mean_absolute_error: 0.0848 - val_r_squared: -0.0406
# Epoch 359/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - mean_absolute_error: 0.0694 - r_squared: 0.2085 - val_loss: 0.0111 - val_mean_squared_error: 0.0111 - val_mean_absolute_error: 0.0846 - val_r_squared: -0.0315
# Epoch 360/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0722 - r_squared: 0.0976 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - val_mean_absolute_error: 0.0847 - val_r_squared: -0.0351
# Epoch 361/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - mean_absolute_error: 0.0683 - r_squared: 0.2508 - val_loss: 0.0113 - val_mean_squared_error: 0.0113 - val_mean_absolute_error: 0.0850 - val_r_squared: -0.0410
# Epoch 362/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - mean_absolute_error: 0.0713 - r_squared: 0.1529 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - val_mean_absolute_error: 0.0850 - val_r_squared: -0.0469
# Epoch 363/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0684 - r_squared: 0.2401 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - val_mean_absolute_error: 0.0850 - val_r_squared: -0.0415
# Epoch 364/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - mean_absolute_error: 0.0703 - r_squared: 0.1877 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - val_mean_absolute_error: 0.0849 - val_r_squared: -0.0425
# Epoch 365/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - mean_absolute_error: 0.0702 - r_squared: 0.1814 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - val_mean_absolute_error: 0.0846 - val_r_squared: -0.0314
# Epoch 366/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - mean_absolute_error: 0.0722 - r_squared: 0.1549 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - val_mean_absolute_error: 0.0846 - val_r_squared: -0.0350
# Epoch 367/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - mean_absolute_error: 0.0733 - r_squared: 0.0821 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - val_mean_absolute_error: 0.0848 - val_r_squared: -0.0390
# Epoch 368/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - mean_absolute_error: 0.0709 - r_squared: 0.1632 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - val_mean_absolute_error: 0.0847 - val_r_squared: -0.0425
# Epoch 369/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - mean_absolute_error: 0.0706 - r_squared: 0.1827 - val_loss: 0.0111 - val_mean_squared_error: 0.0111 - val_mean_absolute_error: 0.0846 - val_r_squared: -0.0384
# Epoch 370/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - mean_absolute_error: 0.0694 - r_squared: 0.1976 - val_loss: 0.0111 - val_mean_squared_error: 0.0111 - val_mean_absolute_error: 0.0845 - val_r_squared: -0.0341
# Epoch 371/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - mean_absolute_error: 0.0724 - r_squared: 0.0987 - val_loss: 0.0110 - val_mean_squared_error: 0.0110 - val_mean_absolute_error: 0.0840 - val_r_squared: -0.0323
# Epoch 372/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - mean_absolute_error: 0.0699 - r_squared: 0.1871 - val_loss: 0.0111 - val_mean_squared_error: 0.0111 - val_mean_absolute_error: 0.0842 - val_r_squared: -0.0366
# Epoch 373/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0695 - r_squared: 0.2226 - val_loss: 0.0110 - val_mean_squared_error: 0.0110 - val_mean_absolute_error: 0.0842 - val_r_squared: -0.0273
# Epoch 374/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - mean_absolute_error: 0.0729 - r_squared: 0.1104 - val_loss: 0.0110 - val_mean_squared_error: 0.0110 - val_mean_absolute_error: 0.0844 - val_r_squared: -0.0305
# Epoch 375/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - mean_absolute_error: 0.0682 - r_squared: 0.2551 - val_loss: 0.0110 - val_mean_squared_error: 0.0110 - val_mean_absolute_error: 0.0844 - val_r_squared: -0.0314
# Epoch 376/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - mean_absolute_error: 0.0687 - r_squared: 0.2208 - val_loss: 0.0111 - val_mean_squared_error: 0.0111 - val_mean_absolute_error: 0.0846 - val_r_squared: -0.0305
# Epoch 377/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - mean_absolute_error: 0.0725 - r_squared: 0.1043 - val_loss: 0.0111 - val_mean_squared_error: 0.0111 - val_mean_absolute_error: 0.0845 - val_r_squared: -0.0253
# Epoch 378/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - mean_absolute_error: 0.0695 - r_squared: 0.1909 - val_loss: 0.0111 - val_mean_squared_error: 0.0111 - val_mean_absolute_error: 0.0843 - val_r_squared: -0.0368
# Epoch 379/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - mean_absolute_error: 0.0710 - r_squared: 0.1268 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - val_mean_absolute_error: 0.0851 - val_r_squared: -0.0593
# Epoch 380/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - mean_absolute_error: 0.0739 - r_squared: 0.0511 - val_loss: 0.0113 - val_mean_squared_error: 0.0113 - val_mean_absolute_error: 0.0853 - val_r_squared: -0.0631
# Epoch 381/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - mean_absolute_error: 0.0689 - r_squared: 0.2246 - val_loss: 0.0113 - val_mean_squared_error: 0.0113 - val_mean_absolute_error: 0.0853 - val_r_squared: -0.0636
# Epoch 382/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - mean_absolute_error: 0.0693 - r_squared: 0.1840 - val_loss: 0.0113 - val_mean_squared_error: 0.0113 - val_mean_absolute_error: 0.0851 - val_r_squared: -0.0620
# Epoch 383/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0690 - r_squared: 0.1693 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - val_mean_absolute_error: 0.0848 - val_r_squared: -0.0552
# Epoch 384/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - mean_absolute_error: 0.0696 - r_squared: 0.1557 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - val_mean_absolute_error: 0.0847 - val_r_squared: -0.0503
# Epoch 385/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - mean_absolute_error: 0.0704 - r_squared: 0.1731 - val_loss: 0.0111 - val_mean_squared_error: 0.0111 - val_mean_absolute_error: 0.0844 - val_r_squared: -0.0411
# Epoch 386/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - mean_absolute_error: 0.0702 - r_squared: 0.1763 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - val_mean_absolute_error: 0.0848 - val_r_squared: -0.0486
# Epoch 387/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - mean_absolute_error: 0.0700 - r_squared: 0.1456 - val_loss: 0.0113 - val_mean_squared_error: 0.0113 - val_mean_absolute_error: 0.0851 - val_r_squared: -0.0546
# Epoch 388/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - mean_absolute_error: 0.0698 - r_squared: 0.2126 - val_loss: 0.0114 - val_mean_squared_error: 0.0114 - val_mean_absolute_error: 0.0854 - val_r_squared: -0.0690
# Epoch 389/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - mean_absolute_error: 0.0703 - r_squared: 0.1619 - val_loss: 0.0113 - val_mean_squared_error: 0.0113 - val_mean_absolute_error: 0.0853 - val_r_squared: -0.0699
# Epoch 390/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - mean_absolute_error: 0.0711 - r_squared: 0.1286 - val_loss: 0.0113 - val_mean_squared_error: 0.0113 - val_mean_absolute_error: 0.0853 - val_r_squared: -0.0546
# Epoch 391/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - mean_absolute_error: 0.0683 - r_squared: 0.2310 - val_loss: 0.0114 - val_mean_squared_error: 0.0114 - val_mean_absolute_error: 0.0855 - val_r_squared: -0.0610
# Epoch 392/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0674 - r_squared: 0.2351 - val_loss: 0.0114 - val_mean_squared_error: 0.0114 - val_mean_absolute_error: 0.0856 - val_r_squared: -0.0638
# Epoch 393/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - mean_absolute_error: 0.0703 - r_squared: 0.1416 - val_loss: 0.0115 - val_mean_squared_error: 0.0115 - val_mean_absolute_error: 0.0857 - val_r_squared: -0.0700
# Epoch 394/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - mean_absolute_error: 0.0693 - r_squared: 0.2027 - val_loss: 0.0113 - val_mean_squared_error: 0.0113 - val_mean_absolute_error: 0.0853 - val_r_squared: -0.0543
# Epoch 395/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0099 - mean_squared_error: 0.0099 - mean_absolute_error: 0.0774 - r_squared: -0.1363 - val_loss: 0.0115 - val_mean_squared_error: 0.0115 - val_mean_absolute_error: 0.0858 - val_r_squared: -0.0706
# Epoch 396/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - mean_absolute_error: 0.0711 - r_squared: 0.1286 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - val_mean_absolute_error: 0.0869 - val_r_squared: -0.0935
# Epoch 397/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0716 - r_squared: 0.1460 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - val_mean_absolute_error: 0.0867 - val_r_squared: -0.1054
# Epoch 398/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0717 - r_squared: 0.1049 - val_loss: 0.0117 - val_mean_squared_error: 0.0117 - val_mean_absolute_error: 0.0862 - val_r_squared: -0.0976
# Epoch 399/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - mean_absolute_error: 0.0694 - r_squared: 0.2067 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - val_mean_absolute_error: 0.0867 - val_r_squared: -0.1233
# Epoch 400/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0692 - r_squared: 0.2151 - val_loss: 0.0117 - val_mean_squared_error: 0.0117 - val_mean_absolute_error: 0.0865 - val_r_squared: -0.1184
# Epoch 401/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0718 - r_squared: 0.1136 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - val_mean_absolute_error: 0.0869 - val_r_squared: -0.1227
# Epoch 402/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - mean_absolute_error: 0.0695 - r_squared: 0.1481 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - val_mean_absolute_error: 0.0868 - val_r_squared: -0.1087
# Epoch 403/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - mean_absolute_error: 0.0738 - r_squared: 0.0060 - val_loss: 0.0117 - val_mean_squared_error: 0.0117 - val_mean_absolute_error: 0.0864 - val_r_squared: -0.0935
# Epoch 404/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - mean_absolute_error: 0.0738 - r_squared: 0.0546 - val_loss: 0.0115 - val_mean_squared_error: 0.0115 - val_mean_absolute_error: 0.0858 - val_r_squared: -0.0725
# Epoch 405/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - mean_absolute_error: 0.0676 - r_squared: 0.2503 - val_loss: 0.0115 - val_mean_squared_error: 0.0115 - val_mean_absolute_error: 0.0859 - val_r_squared: -0.0888
# Epoch 406/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - mean_absolute_error: 0.0697 - r_squared: 0.1731 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - val_mean_absolute_error: 0.0866 - val_r_squared: -0.1306
# Epoch 407/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - mean_absolute_error: 0.0706 - r_squared: 0.1573 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - val_mean_absolute_error: 0.0873 - val_r_squared: -0.1297
# Epoch 408/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - mean_absolute_error: 0.0745 - r_squared: -0.0397 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - val_mean_absolute_error: 0.0873 - val_r_squared: -0.1208
# Epoch 409/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - mean_absolute_error: 0.0726 - r_squared: 0.1210 - val_loss: 0.0117 - val_mean_squared_error: 0.0117 - val_mean_absolute_error: 0.0869 - val_r_squared: -0.1098
# Epoch 410/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - mean_absolute_error: 0.0693 - r_squared: 0.2140 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - val_mean_absolute_error: 0.0863 - val_r_squared: -0.0950
# Epoch 411/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0692 - r_squared: 0.2326 - val_loss: 0.0117 - val_mean_squared_error: 0.0117 - val_mean_absolute_error: 0.0866 - val_r_squared: -0.1040
# Epoch 412/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0718 - r_squared: 0.1445 - val_loss: 0.0117 - val_mean_squared_error: 0.0117 - val_mean_absolute_error: 0.0867 - val_r_squared: -0.1160
# Epoch 413/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - mean_absolute_error: 0.0667 - r_squared: 0.2793 - val_loss: 0.0115 - val_mean_squared_error: 0.0115 - val_mean_absolute_error: 0.0858 - val_r_squared: -0.0944
# Epoch 414/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0677 - r_squared: 0.2490 - val_loss: 0.0114 - val_mean_squared_error: 0.0114 - val_mean_absolute_error: 0.0851 - val_r_squared: -0.0719
# Epoch 415/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - mean_absolute_error: 0.0713 - r_squared: 0.1281 - val_loss: 0.0114 - val_mean_squared_error: 0.0114 - val_mean_absolute_error: 0.0851 - val_r_squared: -0.0633

# %% [markdown]
# ## Reload saved weights from best model

# %%
for test in exps:
    name = autoe[test].run_name
    model_folder = TB_DIR.joinpath(autoe[test]._tb_logdir.joinpath(name))
    autoe[test].model.model_.load_weights(
        TB_DIR.joinpath(model_folder.joinpath(f'{name}.h5'),),
    )
    autoe[test].pred = None
    autoe[test].scores = None

# %% [markdown]
# # Results Visualisation

# %% [markdown]
# ## Loss plot of each trained model

# %%
fig, ax = plt.subplots(1, len(exps),
                       figsize=(10,5),
                       constrained_layout=True,
                       )
# ax = ax.ravel()
for i, test in enumerate(exps):
    axis = fig.axes[i]
    autoe[test].loss_plot(plt_ax=axis)
    axis.set_yscale('log')
    if i > 0:
        axis.set_ylabel('')

# %% [markdown]
# ## Score each model
# - Models scored on train, validation and whole dataset

# %%
for test in exps:
    autoe[test].scores = None
    autoe[test].pred = None

# %%
for test in exps:
    print(f'\n {test}')
    pred_tr, scores_tr = autoe[test].score('train')
    pred_val, scores_val = autoe[test].score('val')
    pred_data, scores_data = autoe[test].score('dataset')
# Out:
#  Test 9
#
# Predicting data:
# 16/16 [==============================] - 0s 1ms/step
#
# Train Scores:
# 	MAE: 0.06637
# 	MSE: 0.00710
# 	R2: 0.52757
#
# Predicting data:
#
# Val Scores:
# 	MAE: 0.08413
# 	MSE: 0.01101
# 	R2: 0.39807
#
# Predicting data:
#
# Dataset Scores:
# 	MAE: 0.15143
# 	MSE: 0.05704
# 	R2: -0.03882

# %% [markdown]
# ## Show histogram of scores across training dataset

# %%
for test in exps:
    fig, ax = autoe[test].hist_scores(['mse'])

# %% [markdown]
# ## Show model recreation capability of training and validation sets

# %%
for test in exps:
    fig, ax = plt.subplots(1, 3, figsize=(15, 3), constrained_layout=True)
    fig.suptitle(f'{autoe[test].RMS.exp_name} - Reconstruction')
    ax = ax.ravel()

    # Training plot
    ax[0] = autoe[test].pred_plot(autoe[test]._ind_tr[0], plt_ax=ax[0])
    ax[0].set_title(f'Training Data - Cut {autoe[test]._ind_tr[0]} \n{ax[0].get_title()}')

    # Validation plot
    ax[1] = autoe[test].pred_plot(autoe[test]._ind_val[0], plt_ax=ax[1])
    ax[1].set_title(f'Val Data - Cut {autoe[test]._ind_val[0]} \n{ax[1].get_title()}')

    # Unseen plot
    i = -100
    ax[2] = autoe[test].pred_plot(i, input=(autoe[test].data, autoe[test].pred), plt_ax=ax[2])
    ax[2].set_title(f'Unseen Data - Cut {i} \n{ax[2].get_title()}')

    for a in ax:
        a.get_legend().remove()
        a.set_xlabel('Samples')
        a.set_ylabel('RMS (V)')

# %% [markdown]
# ## Thresholds for anomaly detection of each model

# %%
for test in exps:
    autoe[test]._thres = None

# %%
for test in exps:
    autoe[test].thres
# Out:
# Cutoffs:
# 	MAE cutoff: 0.07996
# 	MSE cutoff: 0.01014
# 	R2 cutoff: 0.35180

# %% [markdown]
# ## Show scores against threshold

# %%
# metrics = ['mse', 'mae', 'r2']
metrics = ['mse', 'mae']

fig, ax = plt.subplots(len(metrics), len(exps),
                       figsize=(10, 5),
                       constrained_layout=True,
                    #    sharey= 'row',
                       sharex='col',
                       )
axes = fig.axes

for i, test in enumerate(exps):
    for j, met in enumerate(metrics):
        _ = autoe[test].scatter_scores([met], plt_ax=axes[(i + (j * len(exps)))])

        axes[(i)].set_title(test)
        axes[(len(exps) * j) + i].set_ylabel('')
        axes[(len(exps) * j) + i].set_xlabel('')
        if i == 0:
            axes[(len(exps) * j) + i].set_ylabel(f'{met.upper()}')

_ = fig.supxlabel('Cut Number')

# %%
metrics = ['mse', 'mae']

fig, ax = plt.subplots(len(metrics), len(exps),
                       figsize=(10, 6),
                       constrained_layout=True,
                       sharex='col',
                       dpi=500
                       )
axes = fig.axes

for i, test in enumerate(exps):
    for j, met in enumerate(metrics):
        _ = autoe[test].scatter_scores([met], plt_ax=axes[(i + (j * len(exps)))])
        # score = autoe[test].scores[met]
        # axes[(i + (j * len(exps)))].scatter(x=range(len(score)),
        #                                     y=score,
        #                                     s=2,
        #                                     label=met,
        #                                     c='b'
        #                                     )

        axes[(len(exps) * j) + i].axvline(autoe[test]._train_slice.stop, #  * 300, # ONLY FOR LSTMAE WITH JOIN_DF
                                    color='k',
                                    linestyle='--',
                                    alpha=0.5,
                                    )

        axes[(i + (j * len(exps)))].axhline(autoe[test].thres[met], color='r', linestyle='--')

        axes[(i)].set_title(f'Test {i+ 1}')
        axes[(len(exps) * j) + i].set_ylabel('')
        axes[(len(exps) * j) + i].set_xlabel('')
        if i == 0:
            axes[(len(exps) * j) + i].set_ylabel(f'{met.upper()}')

_ = fig.supxlabel('Cut Number')

# %%
dfs = [pd.DataFrame(autoe[test].scores) for test in exps]
df = pd.concat(dfs, keys=exps, names=['Test', 'Metrics'])
for test in exps:
    print(f'\n {test}')
    print(df.loc[test].describe())
# Out:
#  Test 9
#               mae         mse          r2
# count  155.000000  155.000000  155.000000
# mean     0.151433    0.057039   -0.038822
# std      0.111152    0.120530    0.981758
# min      0.048162    0.003758   -6.698376
# 25%      0.077429    0.009245   -0.054155
# 50%      0.124998    0.025033    0.177867
# 75%      0.173582    0.046876    0.390874
# max      0.799934    1.217973    0.795654

# %% [markdown]
# ## autoe models latent space

# %%
# for test in exps:
#     fig, ax = autoe[test].plot_latent_space()

# %% [markdown]
# ## Wear measurements comparison

# %%
metric = ['mse', 'mae']
features = ['Runout', 'Form error']

fig, ax = plt.subplots(len(metric), len(exps),
                    #    figsize=(10, 6),
                       constrained_layout=True,
                    #    sharey= 'row',
                       sharex='col',
                    #    dpi=500,
                       )

ax2 = []

try:
    ax.ravel()
    for a in ax.ravel():
        ax2.append(a.twinx())
except AttributeError:
    ax2.append(ax.twinx())

for a, b in zip(ax2[1:], ax2[0:-1]):
    a.sharey(b)

if len(metric) * len(exps) > 1:
    ax2 = np.reshape(ax2, ax.shape)

axes = fig.axes
axes2 = axes[-(len(axes) // 2):]
axes = axes[0:(len(axes) // 2)]
for i, test in enumerate(exps):
    axes[i].set_title(f'Test {i + 1}')
    # axes[i].set_title(test)

    exp = src.load(test)
    for j, met in enumerate(metric):
        _ = autoe[test].scatter_scores([met], plt_ax=axes[(i + (j * len(exps)))])

        # vert line to show where training data ends
        axes[(len(exps) * j) + i].axvline(autoe[test]._train_slice.stop, # * 300, # ONLY FOR LSTM WITH JOIN_DF
                                    color='k',
                                    linestyle='--',
                                    alpha=0.5,
                                    )

        for feature in features:
            feat = exp.features[feature].drop([0, 1, 2])
            if test == 'Test 5':
                feat = feat.drop([23, 24])
            # axes2[(len(exps) * j) + i].plot(range(len(feat)), feat, label=feature)
            axes2[(len(exps) * j) + i].plot(range(0, len(autoe[test].scores[met])), #, 300), # ONLY FOR LSTM WITH JOIN_DF
                                            feat,
                                            label=feature
                                            )

        axes[(len(exps) * j) + i].set_xlabel('')
        axes[(len(exps) * j) + i].set_ylabel('')
        if i == 0:
            axes[(len(exps) * j) + i].set_ylabel(f'{met.upper()}')
        if i ==len(exps) - 1:
            axes2[(len(exps) * j) + i].set_ylabel('Errors')

_ = fig.supxlabel('Cut Number')

for i, a in enumerate(axes2):
    if (i + 1) % len(exps) != 0:
        plt.setp(a.get_yticklabels(), visible=False)

# axes[0].set_ylim([0, 0.05])

l1, lab1 = axes[0].get_legend_handles_labels()
l2, lab2 = axes2[0].get_legend_handles_labels()

plt.figlegend(l1 + l2,
              ['Metric'] + lab2, 
              loc='upper center', 
              bbox_to_anchor=(0.5, 0),
              ncol=len(l1 + l2)
              )
plt.tight_layout()
# Out:
# /tmp/ipykernel_467/1106150093.py:79: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
encoder = autoe[test].model.model_.get_layer('Encoder')
en_data = encoder.predict(autoe[test].data)
plt.plot(en_data)
# Out:
# 5/5 [==============================] - 0s 2ms/step
# [<matplotlib.lines.Line2D at 0x7ff5fb34fc10>,
#  <matplotlib.lines.Line2D at 0x7ff5fb34fc70>,
#  <matplotlib.lines.Line2D at 0x7ff5fb34fca0>,
#  <matplotlib.lines.Line2D at 0x7ff5fb34fd90>,
#  <matplotlib.lines.Line2D at 0x7ff5fb34fe80>,
#  <matplotlib.lines.Line2D at 0x7ff5fb34ff70>,
#  <matplotlib.lines.Line2D at 0x7ff5fb3740a0>,
#  <matplotlib.lines.Line2D at 0x7ff5fb374190>,
#  <matplotlib.lines.Line2D at 0x7ff5fb374280>,
#  <matplotlib.lines.Line2D at 0x7ff5fb374370>,
#  <matplotlib.lines.Line2D at 0x7ff5fb34fc40>,
#  <matplotlib.lines.Line2D at 0x7ff5fb374460>,
#  <matplotlib.lines.Line2D at 0x7ff5fb374550>,
#  <matplotlib.lines.Line2D at 0x7ff5fb374700>,
#  <matplotlib.lines.Line2D at 0x7ff5fb3747f0>,
#  <matplotlib.lines.Line2D at 0x7ff5fb3748e0>]

# %%
for test in exps:
    fig, ax = plt.subplots(figsize=(10, 4), dpi=200)
    try:
        autoe[test].anom_plot(anomaly_metric='mse', plt_ax=ax)
    except AttributeError:
        pass

# %%
import seaborn as sns

fig, ax = plt.subplots(1, len(exps), figsize=(10,5), constrained_layout=True)
try:
    ax = ax.ravel()
except AttributeError:
    ax = [ax]

for i, test in enumerate(exps):
    a = autoe[test]
    sc = a.scores['mse'][a._ind_tr]

    def mad_based_outlier(points, thresh=2):
        if len(points.shape) == 1:
            points = points[:,None]
        median = np.median(points, axis=0)
        diff = np.sum((points - median)**2, axis=-1)
        diff = np.sqrt(diff)
        med_abs_deviation = np.median(diff)

        modified_z_score = 0.6745 * diff / med_abs_deviation

        return modified_z_score > thresh

    outliers = sc[mad_based_outlier(sc)]
    print(np.min(outliers))

    sns.histplot(sc, ax=ax[i], kde=True, log_scale=False, bins=50)
    ax[i].plot(outliers, np.zeros_like(outliers), 'ro', clip_on=False)
# Out:
# 0.010917589692491394

# %% [markdown]
# # Try Transfer Learning

# %%
# First try the the model on the one used dataset and see how it performs
df_t9 = rms['Test 9'].data
jr_t9= []
for i in range(np.shape(df_t9)[1]):
    jr_t9.extend(df_t9.iloc[:, i].values.T)
jr_t9 = np.array(jr_t9).reshape(-1, 1)
print(f'Number of RMS samples: {np.shape(jr_t9)}')

assert ~np.isnan(jr_t9).any(), 'NaN values in RMS data'

# scale
jr_t9 = autoe['join_rms'].scaler.transform(jr_t9)

# sequence data
seq_t9 = autoe['join_rms'].sequence_inputs(jr_t9, autoe['join_rms'].seq_len)
print(f'Sequence data shape: {np.shape(seq_t9)}')

# predict
pred_t9 = autoe['join_rms'].model.predict(seq_t9)
# Out:
# Number of RMS samples: (46500, 1)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[162], line 12
#       9 assert ~np.isnan(jr_t9).any(), 'NaN values in RMS data'
#      11 # scale
# ---> 12 jr_t9 = autoe['join_rms'].scaler.transform(jr_t9)
#      14 # sequence data
#      15 seq_t9 = autoe['join_rms'].sequence_inputs(jr_t9, autoe['join_rms'].seq_len)
#
# KeyError: 'join_rms'

# %%
# score
i = 40000
autoe['join_rms'].pred_plot(i, input=(seq_t9, pred_t9))

# %%
(x, pred), scores = autoe['join_rms'].score(x=(seq_t9), tb=False)

# %%
metric = ['mse', 'mae', 'r2']
features = ['Runout', 'Form error']

fig, ax = plt.subplots(len(metric), len(exps),
                       figsize=(10, 6),
                       constrained_layout=True,
                    #    sharey= 'row',
                       sharex='col',
                       dpi=500,
                       )

ax2 = []

try:
    ax.ravel()
    for a in ax.ravel():
        ax2.append(a.twinx())
except AttributeError:
    ax2.append(ax.twinx())

for a, b in zip(ax2[1:], ax2[0:-1]):
    a.sharey(b)

if len(metric) * len(exps) > 1:
    ax2 = np.reshape(ax2, ax.shape)

axes = fig.axes
axes2 = axes[-(len(axes) // 2):]
axes = axes[0:(len(axes) // 2)]
for i, test in enumerate(['Test 9']):
    axes[i].set_title(test)

    exp = src.load(test)
    for j, met in enumerate(metric):
        score = scores[met]
        axes[(i + (j * len(exps)))].scatter(x=range(len(score)),
                                            y=score,
                                            s=2,
                                            label=met,
                                            c='b'
                                            )

        axes[(i + (j * len(exps)))].axhline(autoe['join_rms'].thres[met], color='r', linestyle='--')

        # vert line to show where training data ends
        # axes[(len(exps) * j) + i].axvline(autoe[test]._train_slice.stop * 300,
        #                             color='k',
        #                             linestyle='--',
        #                             alpha=0.5,
        #                             )

        for feature in features:
            feat = exp.features[feature].drop([0, 1, 2])
            if test == 'Test 5':
                feat = feat.drop([23, 24])
            # axes2[(len(exps) * j) + i].plot(range(len(feat)), feat, label=feature)
            axes2[(len(exps) * j) + i].plot(range(0, len(scores[met]), 300), feat, label=feature)

        axes[(len(exps) * j) + i].set_xlabel('')
        axes[(len(exps) * j) + i].set_ylabel('')
        if i == 0:
            axes[(len(exps) * j) + i].set_ylabel(f'{met.upper()}')
        if i ==len(exps) - 1:
            axes2[(len(exps) * j) + i].set_ylabel('Errors')

_ = fig.supxlabel('Cut Number')

for i, a in enumerate(axes2):
    if (i + 1) % len(exps) != 0:
        plt.setp(a.get_yticklabels(), visible=False)

l1, lab1 = axes[0].get_legend_handles_labels()
l2, lab2 = axes2[0].get_legend_handles_labels()

plt.figlegend(l1 + l2,
              ['Metric'] + lab2, 
              loc='upper center', 
              bbox_to_anchor=(0.5, 0),
              ncol=len(l1 + l2)
              )
plt.tight_layout()

# %%
# Then try transfer learning with the other dataset to see if the model requires less training to perform well
autoe_2 = LSTMAutoEncoder(rms['Test 9'],
                          rms['Test 9'].data,
                          tb=True,
                          tb_logdir='LSTMAE_test',
                          train_slice=(0, 50),
                          val_frac=0.33,
                          params={'epochs': 300,
                                  'batch_size': 64,
                                  'n_size': [256, 128, 64],
                                  'seq_len': 100,
                                  'n_bottleneck': 32,
                                  'loss': 'mean_squared_error',
                                  'callbacks': [
                                          tf.keras.callbacks.EarlyStopping(
                                            monitor='val_loss',
                                            patience=10,
                                            mode='min',
                                            start_from_epoch= 150,
                                            ),
                                     ]
                          }
                    )

# %%
name = autoe_2.run_name
model_folder = TB_DIR.joinpath(autoe_2._tb_logdir.joinpath(name))
if not os.path.exists(model_folder):
    os.makedirs(model_folder)
assert os.path.exists(model_folder)

autoe_2.model.callbacks.append(
    tf.keras.callbacks.ModelCheckpoint(
    filepath=model_folder.joinpath(f'{name}.h5'),
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_weights_only=True,
    )
)

autoe_2.model.initialize(X=autoe_2.train_data[0], y=autoe_2.train_data[0])

# %%
name = autoe['join_rms'].run_name
model_folder = TB_DIR.joinpath(autoe['join_rms']._tb_logdir.joinpath(name))
autoe_2.model.model_.load_weights(
    TB_DIR.joinpath(model_folder.joinpath(f'{name}.h5'),),
)

# %%
# Make the Encoder static so training only occurs on the Decoder.
autoe_2.model.model_.get_layer('Encoder').trainable = False
autoe_2.model.model_.get_layer('Encoder').trainable

# %%
autoe_2.fit(x=autoe_2.train_data,
            val_data=autoe_2.val_data,
            verbose=0,
            use_multiprocessing=True,
            )

# %%
name = autoe_2.run_name
model_folder = TB_DIR.joinpath(autoe_2._tb_logdir.joinpath(name))
autoe_2.model.model_.load_weights(
    TB_DIR.joinpath(model_folder.joinpath(f'{name}.h5'),),
)
autoe_2.pred = None
autoe_2.scores = None

# %%
pred_tr, scores_tr = autoe_2.score('train')
pred_val, scores_val = autoe_2.score('val')
pred_data, scores_data = autoe_2.score('dataset')

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,3), constrained_layout=True)
fig.suptitle(f'{autoe_2.RMS.exp_name} - Reconstruction')
ax = ax.ravel()

# Training plot
ax[0] = autoe_2.pred_plot(autoe_2._ind_tr[0], plt_ax=ax[0])
ax[0].set_title(f'Training Data - Cut {autoe_2._ind_tr[0]} \n{ax[0].get_title()}')

# Validation plot
ax[1] = autoe_2.pred_plot(autoe_2._ind_val[0], plt_ax=ax[1])
ax[1].set_title(f'Val Data - Cut {autoe_2._ind_val[0]} \n{ax[1].get_title()}')

# Unseen plot
i = -100
ax[2] = autoe_2.pred_plot(i, input=(autoe_2.data, autoe_2.pred), plt_ax=ax[2])
ax[2].set_title(f'Unseen Data - Cut {i} \n{ax[2].get_title()}')

# %%
metric = ['mse', 'mae']
features = ['Runout', 'Form error']

fig, ax = plt.subplots(len(metric), len(exps),
                       figsize=(10, 6),
                       constrained_layout=True,
                    #    sharey= 'row',
                       sharex='col',
                       dpi=500,
                       )

ax2 = []

try:
    ax.ravel()
    for a in ax.ravel():
        ax2.append(a.twinx())
except AttributeError:
    ax2.append(ax.twinx())

for a, b in zip(ax2[1:], ax2[0:-1]):
    a.sharey(b)

if len(metric) * len(exps) > 1:
    ax2 = np.reshape(ax2, ax.shape)

axes = fig.axes
axes2 = axes[-(len(axes) // 2):]
axes = axes[0:(len(axes) // 2)]
for i, test in enumerate(['Test 9']):
    axes[i].set_title(f'Test {i + 1}')
    # axes[i].set_title(test)

    exp = src.load(test)
    for j, met in enumerate(metric):
        _ = autoe_2.scatter_scores([met], plt_ax=axes[(i + (j * len(exps)))])

        # vert line to show where training data ends
        axes[(len(exps) * j) + i].axvline(autoe_2._train_slice.stop * 300,
                                    color='k',
                                    linestyle='--',
                                    alpha=0.5,
                                    )

        for feature in features:
            feat = exp.features[feature].drop([0, 1, 2])
            if test == 'Test 5':
                feat = feat.drop([23, 24])
            # axes2[(len(exps) * j) + i].plot(range(len(feat)), feat, label=feature)
            axes2[(len(exps) * j) + i].plot(range(0, len(autoe_2.scores[met]), 300), feat, label=feature)

        axes[(len(exps) * j) + i].set_xlabel('')
        axes[(len(exps) * j) + i].set_ylabel('')
        if i == 0:
            axes[(len(exps) * j) + i].set_ylabel(f'{met.upper()}')
        if i ==len(exps) - 1:
            axes2[(len(exps) * j) + i].set_ylabel('Errors')

_ = fig.supxlabel('Cut Number')

for i, a in enumerate(axes2):
    if (i + 1) % len(exps) != 0:
        plt.setp(a.get_yticklabels(), visible=False)

l1, lab1 = axes[0].get_legend_handles_labels()
l2, lab2 = axes2[0].get_legend_handles_labels()

plt.figlegend(l1 + l2,
              ['Metric'] + lab2, 
              loc='upper center', 
              bbox_to_anchor=(0.5, 0),
              ncol=len(l1 + l2)
              )
plt.tight_layout()

# %%
# autoe_3 is with only the final layer of the decoder being trained rather than autoe_2 where the entire decoder is trained.
autoe_3 = LSTMAutoEncoder(rms['Test 9'],
                          rms['Test 9'].data,
                          tb=True,
                          tb_logdir='LSTMAE_test',
                          train_slice=(0, 50),
                          val_frac=0.33,
                          params={'epochs': 300,
                                  'batch_size': 64,
                                  'n_size': [256, 128, 64],
                                  'seq_len': 100,
                                  'n_bottleneck': 32,
                                  'loss': 'mean_squared_error',
                                  'callbacks': [
                                          tf.keras.callbacks.EarlyStopping(
                                            monitor='val_loss',
                                            patience=10,
                                            mode='min',
                                            start_from_epoch= 150,
                                            ),
                                     ]
                          }
                    )

# %%
name = autoe_3.run_name
model_folder = TB_DIR.joinpath(autoe_3._tb_logdir.joinpath(name))
if not os.path.exists(model_folder):
    os.makedirs(model_folder)
assert os.path.exists(model_folder)

autoe_3.model.callbacks.append(
    tf.keras.callbacks.ModelCheckpoint(
    filepath=model_folder.joinpath(f'{name}.h5'),
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_weights_only=True,
    )
)

autoe_3.model.initialize(X=autoe_3.train_data[0], y=autoe_3.train_data[0])

# %%
name = autoe['join_rms'].run_name
model_folder = TB_DIR.joinpath(autoe['join_rms']._tb_logdir.joinpath(name))
autoe_3.model.model_.load_weights(
    TB_DIR.joinpath(model_folder.joinpath(f'{name}.h5'),),
)

# %%
# Make the Encoder static so training only occurs on the Decoder.
autoe_3.model.model_.get_layer('Encoder').trainable = False
autoe_3.model.model_.get_layer('Encoder').trainable

# %%
# Change so that only last layer of decoder is trainable
decoder = autoe_3.model.model_.get_layer('Decoder')
for i, layer in enumerate(decoder.layers):
    if i < 8:
        layer.trainable = False

# %%
autoe_3.fit(x=autoe_3.train_data,
            val_data=autoe_3.val_data,
            verbose=0,
            use_multiprocessing=True,
            )

# %%
name = autoe_3.run_name
model_folder = TB_DIR.joinpath(autoe_3._tb_logdir.joinpath(name))
autoe_3.model.model_.load_weights(
    TB_DIR.joinpath(model_folder.joinpath(f'{name}.h5'),),
)
autoe_3.pred = None
autoe_3.scores = None

# %%
pred_tr, scores_tr = autoe_3.score('train')
pred_val, scores_val = autoe_3.score('val')
pred_data, scores_data = autoe_3.score('dataset')

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,3), constrained_layout=True)
fig.suptitle(f'{autoe_3.RMS.exp_name} - Reconstruction')
ax = ax.ravel()

# Training plot
ax[0] = autoe_3.pred_plot(autoe_3._ind_tr[0], plt_ax=ax[0])
ax[0].set_title(f'Training Data - Cut {autoe_3._ind_tr[0]} \n{ax[0].get_title()}')

# Validation plot
ax[1] = autoe_3.pred_plot(autoe_3._ind_val[0], plt_ax=ax[1])
ax[1].set_title(f'Val Data - Cut {autoe_3._ind_val[0]} \n{ax[1].get_title()}')

# Unseen plot
i = -100
ax[2] = autoe_3.pred_plot(i, input=(autoe_3.data, autoe_3.pred), plt_ax=ax[2])
ax[2].set_title(f'Unseen Data - Cut {i} \n{ax[2].get_title()}')

# %%
metric = ['mse', 'mae']
features = ['Runout', 'Form error']

fig, ax = plt.subplots(len(metric), len(exps),
                       figsize=(10, 6),
                       constrained_layout=True,
                    #    sharey= 'row',
                       sharex='col',
                       dpi=500,
                       )

ax2 = []

try:
    ax.ravel()
    for a in ax.ravel():
        ax2.append(a.twinx())
except AttributeError:
    ax2.append(ax.twinx())

for a, b in zip(ax2[1:], ax2[0:-1]):
    a.sharey(b)

if len(metric) * len(exps) > 1:
    ax2 = np.reshape(ax2, ax.shape)

axes = fig.axes
axes2 = axes[-(len(axes) // 2):]
axes = axes[0:(len(axes) // 2)]
for i, test in enumerate(['Test 9']):
    axes[i].set_title(f'Test {i + 1}')
    # axes[i].set_title(test)

    exp = src.load(test)
    for j, met in enumerate(metric):
        _ = autoe_3.scatter_scores([met], plt_ax=axes[(i + (j * len(exps)))])

        # vert line to show where training data ends
        axes[(len(exps) * j) + i].axvline(autoe_3._train_slice.stop * 300,
                                    color='k',
                                    linestyle='--',
                                    alpha=0.5,
                                    )

        for feature in features:
            feat = exp.features[feature].drop([0, 1, 2])
            if test == 'Test 5':
                feat = feat.drop([23, 24])
            # axes2[(len(exps) * j) + i].plot(range(len(feat)), feat, label=feature)
            axes2[(len(exps) * j) + i].plot(range(0, len(autoe_3.scores[met]), 300), feat, label=feature)

        axes[(len(exps) * j) + i].set_xlabel('')
        axes[(len(exps) * j) + i].set_ylabel('')
        if i == 0:
            axes[(len(exps) * j) + i].set_ylabel(f'{met.upper()}')
        if i ==len(exps) - 1:
            axes2[(len(exps) * j) + i].set_ylabel('Errors')

_ = fig.supxlabel('Cut Number')

for i, a in enumerate(axes2):
    if (i + 1) % len(exps) != 0:
        plt.setp(a.get_yticklabels(), visible=False)

l1, lab1 = axes[0].get_legend_handles_labels()
l2, lab2 = axes2[0].get_legend_handles_labels()

plt.figlegend(l1 + l2,
              ['Metric'] + lab2, 
              loc='upper center', 
              bbox_to_anchor=(0.5, 0),
              ncol=len(l1 + l2)
              )
plt.tight_layout()
